# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

from tqdm import tqdm
import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
#import resnest.torch as resnest_torch

from dataset import SpectrogramDataset



ROOT = Path.cwd()
INPUT_ROOT = ROOT / "../machine_sound"#ROOT / "data/wav_data"


tmp_list = []
for decibel_value in INPUT_ROOT.iterdir():
    for machine in decibel_value.iterdir():
        if machine.is_file():
            continue
        machine_type = machine.stem
        print(f"Reading files in {machine_type} machine type")
        for id in machine.iterdir():
            if id.is_file():
                continue
            id_type = id.stem
            print(f"Reading files in {id_type}")
            for operation in id.iterdir():
                if operation.is_file():
                    continue
                operation_type = operation.stem
                assert operation_type in ["normal", "abnormal"], "Expected normal or abnormal"
                for wav_f in operation.iterdir():
                    if wav_f.is_file() and wav_f.suffix == ".wav":
                        tmp_list.append( [machine_type, id_type, operation_type,
                                          wav_f.name, wav_f.as_posix()])

train_all = pd.DataFrame(
    tmp_list, columns=["machine_type", "id_type", "operation_type",
                        "wav_filename", "wav_file_path"])

print(train_all.sample(5))
print('All df shape ', train_all.shape)

train_df, val_df = train_test_split(train_all, test_size=0.2, random_state=1213)

print('Train df shape ', train_df.shape)
print('Test df shape ', val_df.shape)


def get_loaders_for_training(args_dataset: tp.Dict, args_loader: tp.Dict, \
                             train_file_list: tp.List[str], val_file_list: tp.List[str]):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])

    return train_loader, val_loader, train_dataset, val_dataset


train_file_list = train_df[["wav_file_path", "machine_type"]].values.tolist()
val_file_list = val_df[["wav_file_path", "machine_type"]].values.tolist()

print("train: {}, val: {}".format(len(train_file_list), len(val_file_list)))

with open("./test_config.yaml") as settings_str:
    settings = yaml.safe_load(settings_str)

# for k, v in settings.items():
#     print("[{}]".format(k))
#     print(v)

# # # get loader
train_loader, val_loader, train_dataset, val_dataset = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)


# # for batch_idx, (data, target) in enumerate(train_loader):
# #     #data, target = data.to(device), target.to(device)
# #     print(data, target)
# train_iter = iter(train_loader)
# data, target = train_iter.next()
# print(data,target)
# print("END")
# Out:
# Reading files in pump machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in .ipynb_checkpoints machine type
# Reading files in abnormal machine type
# Reading files in .ipynb_checkpoints
# Reading files in normal machine type
# Reading files in slider machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in slider machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in pump machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in pump machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in fan machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in fan machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in fan machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in valve machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in valve machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in slider machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
# Reading files in valve machine type
# Reading files in id_04
# Reading files in id_00
# Reading files in id_06
# Reading files in id_02
#       machine_type id_type operation_type  wav_filename  \
# 15830         pump   id_02         normal  00000672.wav
# 18126         pump   id_00         normal  00000015.wav
# 39359        valve   id_00         normal  00000176.wav
# 53463        valve   id_02         normal  00000403.wav
# 22133          fan   id_04         normal  00000614.wav
#
#                                            wav_file_path
# 15830  /home/ubuntu/anudeep/machine_sound_classificat...
# 18126  /home/ubuntu/anudeep/machine_sound_classificat...
# 39359  /home/ubuntu/anudeep/machine_sound_classificat...
# 53463  /home/ubuntu/anudeep/machine_sound_classificat...
# 22133  /home/ubuntu/anudeep/machine_sound_classificat...
# All df shape  (54057, 5)
# Train df shape  (43245, 5)
# Test df shape  (10812, 5)
# train: 43245, val: 10812

# %%
for ctr, (data, target) in enumerate(train_loader):
    print(target)

# %%
data, target = train_dataset.__getitem__(3)
#data = data[:, 0]
print(data.shape)
print(train_dataset.file_list[3])
# Out:
# (64, 313)
# ['/home/ubuntu/anudeep/machine_sound_classification/../machine_sound/neg6_dB_pump/pump/id_00/normal/00000780.wav', 'pump']

# %%
import matplotlib.pyplot as plt
import librosa.display
import librosa
import soundfile as sf
from IPython.display import Audio

for k in range(1):
#     fig = plt.figure(figsize=(24, 6))
#     plt.subplot(1, 2, 1)
#     #librosa.display.specshow(data, sr=16000, hop_length=512, x_axis='time', y_axis='mel', cmap='viridis')
#     plt.xlabel('Time (s)')
#     plt.ylabel('Frequency (Hz)')
#     plt.colorbar(format='%+2.0f dB')
    
    S = librosa.feature.inverse.mel_to_audio(data)
    #y = librosa.griffinlim(S)
    
    #print(type(S), S.shape)
    sf.write("./spec_audio.wav", S, 16000)
    Audio("./spec_audio.wav")

# %%
Audio("./spec_audio.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("./spec_audio_original.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier
MACHINE_CODE = {
    'pump': 0, 'valve': 1, 'slider': 2, 'fan': 3
}

classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-xvect-voxceleb", savedir="pretrained_models/spkrec-xvect-voxceleb")

# %%
embeddings = []
labels = []
for k in range(0,len(train_all['wav_file_path'])):
    print(k, end="\r", flush=True)
    signal, fs =torchaudio.load(train_all['wav_file_path'][k])
    embeddings.append(classifier.encode_batch(signal[0]).numpy())
    labels.append(MACHINE_CODE[train_all['machine_type'][k]])
# Out:
# 54056

# %%
embeddings = np.squeeze(np.squeeze(np.array(embeddings), axis=1), axis=1)
labels = np.array(labels)
embeddings.shape, labels.shape
# Out:
# ((54057, 512), (54057,))

# %%
embeddings.shape, labels.shape
# Out:
# ((54057, 512), (54057,))

# %% [markdown]
# # PCA and T-SNE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import seaborn


tsne = TSNE(random_state=0, verbose=1)
tsne_results = tsne.fit_transform(embeddings)

tsne_results=pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])
tsne_results['label'] = labels
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 54057 samples in 0.026s...
# [t-SNE] Computed neighbors for 54057 samples in 93.842s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 54057
# [t-SNE] Computed conditional probabilities for sample 2000 / 54057
# [t-SNE] Computed conditional probabilities for sample 3000 / 54057
# [t-SNE] Computed conditional probabilities for sample 4000 / 54057
# [t-SNE] Computed conditional probabilities for sample 5000 / 54057
# [t-SNE] Computed conditional probabilities for sample 6000 / 54057
# [t-SNE] Computed conditional probabilities for sample 7000 / 54057
# [t-SNE] Computed conditional probabilities for sample 8000 / 54057
# [t-SNE] Computed conditional probabilities for sample 9000 / 54057
# [t-SNE] Computed conditional probabilities for sample 10000 / 54057
# [t-SNE] Computed conditional probabilities for sample 11000 / 54057
# [t-SNE] Computed conditional probabilities for sample 12000 / 54057
# [t-SNE] Computed conditional probabilities for sample 13000 / 54057
# [t-SNE] Computed conditional probabilities for sample 14000 / 54057
# [t-SNE] Computed conditional probabilities for sample 15000 / 54057
# [t-SNE] Computed conditional probabilities for sample 16000 / 54057
# [t-SNE] Computed conditional probabilities for sample 17000 / 54057
# [t-SNE] Computed conditional probabilities for sample 18000 / 54057
# [t-SNE] Computed conditional probabilities for sample 19000 / 54057
# [t-SNE] Computed conditional probabilities for sample 20000 / 54057
# [t-SNE] Computed conditional probabilities for sample 21000 / 54057
# [t-SNE] Computed conditional probabilities for sample 22000 / 54057
# [t-SNE] Computed conditional probabilities for sample 23000 / 54057
# [t-SNE] Computed conditional probabilities for sample 24000 / 54057
# [t-SNE] Computed conditional probabilities for sample 25000 / 54057
# [t-SNE] Computed conditional probabilities for sample 26000 / 54057
# [t-SNE] Computed conditional probabilities for sample 27000 / 54057
# [t-SNE] Computed conditional probabilities for sample 28000 / 54057
# [t-SNE] Computed conditional probabilities for sample 29000 / 54057
# [t-SNE] Computed conditional probabilities for sample 30000 / 54057
# [t-SNE] Computed conditional probabilities for sample 31000 / 54057
# [t-SNE] Computed conditional probabilities for sample 32000 / 54057
# [t-SNE] Computed conditional probabilities for sample 33000 / 54057
# [t-SNE] Computed conditional probabilities for sample 34000 / 54057
# [t-SNE] Computed conditional probabilities for sample 35000 / 54057
# [t-SNE] Computed conditional probabilities for sample 36000 / 54057
# [t-SNE] Computed conditional probabilities for sample 37000 / 54057
# [t-SNE] Computed conditional probabilities for sample 38000 / 54057
# [t-SNE] Computed conditional probabilities for sample 39000 / 54057
# [t-SNE] Computed conditional probabilities for sample 40000 / 54057
# [t-SNE] Computed conditional probabilities for sample 41000 / 54057
# [t-SNE] Computed conditional probabilities for sample 42000 / 54057
# [t-SNE] Computed conditional probabilities for sample 43000 / 54057
# [t-SNE] Computed conditional probabilities for sample 44000 / 54057
# [t-SNE] Computed conditional probabilities for sample 45000 / 54057
# [t-SNE] Computed conditional probabilities for sample 46000 / 54057
# [t-SNE] Computed conditional probabilities for sample 47000 / 54057
# [t-SNE] Computed conditional probabilities for sample 48000 / 54057
# [t-SNE] Computed conditional probabilities for sample 49000 / 54057
# [t-SNE] Computed conditional probabilities for sample 50000 / 54057
# [t-SNE] Computed conditional probabilities for sample 51000 / 54057
# [t-SNE] Computed conditional probabilities for sample 52000 / 54057
# [t-SNE] Computed conditional probabilities for sample 53000 / 54057
# [t-SNE] Computed conditional probabilities for sample 54000 / 54057
# [t-SNE] Computed conditional probabilities for sample 54057 / 54057
# [t-SNE] Mean sigma: 3.426497
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 96.780159
# [t-SNE] KL divergence after 1000 iterations: 2.609790

# %%
seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_results, x='tsne1', y='tsne2', hue='machine_label', palette="dark", s=10)

plt.show()

# %%
tsne_results['bin_label'] = train_all['operation_type']
tsne_results['machine_label'] = train_all['machine_type']

# %%
seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_results, x='tsne1', y='tsne2', hue='bin_label', palette="dark", s=10)

plt.show()

# %%
tsne_pump = tsne_results[tsne_results["machine_label"] == 'pump']
tsne_slider = tsne_results[tsne_results["machine_label"] == 'slider']
tsne_valve = tsne_results[tsne_results["machine_label"] == 'valve']
tsne_fan = tsne_results[tsne_results["machine_label"] == 'fan']

f, ax = plt.subplots(2,2,figsize=(10, 10))
seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_pump, x='tsne1', y='tsne2', hue='bin_label', palette="dark", s=10, ax=ax[0][0]).set_title('pump')

#plt.show()

seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_slider, x='tsne1', y='tsne2', hue='bin_label', palette="dark", s=10, ax=ax[0][1]).set_title('slider')

#plt.show()

seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_valve, x='tsne1', y='tsne2', hue='bin_label', palette="dark", s=10, ax=ax[1][0]).set_title('valve')

#plt.show()

seaborn.set(rc={'figure.figsize':(20,16)})
seaborn.scatterplot(data=tsne_fan, x='tsne1', y='tsne2', hue='bin_label', palette="dark", s=10, ax=ax[1][1]).set_title('fan')

plt.show()
